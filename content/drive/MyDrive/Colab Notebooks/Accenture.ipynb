# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68d90639-84c8-48be-a323-5394107b3876" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68d90639-84c8-48be-a323-5394107b3876">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/ReactionTypes.csv')

# %%
print("Original Dataset:")
print(df.head())
# Out:
# Original Dataset:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
df_cleaned = df.drop(columns=['Unnamed: 0'])

# %%
print("/nMissing values after cleaning:")
print(df_cleaned.isnull().sum())
# Out:
# /nCleaned Dataset:
# Type         0
# Sentiment    0
# Score        0
# dtype: int64

# %%
print("\nData types after cleaning:")
print(df_cleaned.dtypes)
# Out:
# Data types after cleaning:
# Type         object
# Sentiment    object
# Score         int64
# dtype: object

# %%
print("/nCleaned Dataset:")
print(df_cleaned.head())
# Out:
# /nCleaned Dataset:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %%
df_cleaned.to_csv('cleaned.reaction.types.csv', index=False)
print("\nCleaned dataset saved as 'cleaned.reaction.types.csv'")
# Out:
# Cleaned dataset saved as 'cleaned.reaction.types.csv'

# %%
files.download('cleaned.reaction.types.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-95404826-b259-4b5c-a6de-809fe6476b3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95404826-b259-4b5c-a6de-809fe6476b3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/Reactions.csv')

# %%
print("Original Dataset:")
print(df.head())
# Out:
# Original Dataset:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
df_cleaned = df.drop(columns=['Unnamed: 0'])

# %%
print("/nMissing values after cleaning:")
print(df_cleaned.isnull().sum())
# Out:
# /nMissing values after cleaning:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
print("\nData types after cleaning:")
print(df_cleaned.dtypes)
# Out:
# Data types after cleaning:
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# dtype: object

# %%
print("/nCleaned Dataset:")
print(df_cleaned.head())
# Out:
# /nCleaned Dataset:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2                                   NaN
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
#
#       Type             Datetime
# 0      NaN  2021-04-22 15:17:15
# 1  disgust  2020-11-07 09:43:50
# 2  dislike  2021-06-17 12:22:51
# 3   scared  2021-04-18 05:13:58
# 4  disgust  2021-01-06 19:13:01

# %%
df_cleaned.to_csv('cleaned.reaction.csv', index=False)
print("\nCleaned dataset saved as 'cleaned.reaction.types.csv'")
# Out:
# Cleaned dataset saved as 'cleaned.reaction.types.csv'

# %%
files.download('cleaned.reaction.csv')
