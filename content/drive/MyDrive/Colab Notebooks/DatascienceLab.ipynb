# %%
import pandas as pd
s1=pd.Series([1,2,3,4,5])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd
pd.Series({'a':10,'b':20,'c':30})
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
import pandas as pd
p1=pd.Series({'a':10,'b':20,'c':30}, index=['c','a','b'])
p1.astype(int)
# Out:
# c    30
# a    10
# b    20
# dtype: int64

# %%
p1=pd.Series([2,5,4,7,8,9,2,5,2])
p1[4]
# Out:
# 5

# %%
p1=pd.Series([2,5,4,7,8,9,2,5,2])
p1[:6]
p1[:6].astype(float)
# Out:
# 0    2.0
# 1    5.0
# 2    4.0
# 3    7.0
# 4    8.0
# 5    9.0
# dtype: float64

# %%
p1=pd.Series([2,4,6,7,8,3,5,6,2,4,8,6])
p1[-3:]
# Out:
# 9     4
# 10    8
# 11    6
# dtype: int64

# %%
s1=pd.Series([2,4,5,6,7,4,6])
s2=pd.Series([5,3,1,7,5,5,5])
s3=s1+s2
s3.astype(float)
# Out:
# 0     7.0
# 1     7.0
# 2     6.0
# 3    13.0
# 4    12.0
# 5     9.0
# 6    11.0
# dtype: float64

# %%
import pandas as pd
pd.DataFrame({"Name":['khushi','nizam','tejaswa','vishwas'],"Marks":[90,65,77,58]})
# Out:
#       Name  Marks
# 0   khushi     90
# 1    nizam     65
# 2  tejaswa     77
# 3  vishwas     58
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
